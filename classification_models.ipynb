# %%
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import warnings

# %%
df = pd.read_csv('totalwithmaininfo.csv',sep=',')
df = df.drop(df.columns[0],axis=1)

# %%
train_percentage = 13/22
train_index = int(len(df)*train_percentage)
test_index = len(df)-train_index

# %%
df_train = df[:train_index]
df_test = df[-test_index:]

# %%
X_test = df_test.drop(["Y"],axis=1)
y_test = df_test["Y"]

# %%
X_train = df_train.drop('Y',axis=1)
y_train = df_train['Y']

# %%
def average(y_pred):
  for i in range(len(y_pred)):
    if i % 240 == 0 or (i+1) % 240 == 0:
      pass
    else: 
      average = float(y_pred[i-1] +  y_pred[i] + y_pred[i+1])/3
      if average >= 0.5:
        y_pred[i] = 1
      else:
        y_pred[i] = 0
  return y_pred

# %% [markdown]
# ## 1. Logistic Regression

# %%
clf = LogisticRegression().fit(X_train, y_train)
y_pred_1 = clf.predict(X_test)
y_pred_1 = average(y_pred_1)
y_score_1 = clf.predict_proba(X_test)[:,1]
acc1 = accuracy_score(y_test, y_pred_1)
f1_score_1 = metrics.f1_score(y_test, y_pred_1)
roc_1 = metrics.roc_auc_score(y_test, y_score_1)
print([acc1,f1_score_1,roc_1])
print(confusion_matrix(y_test, y_pred_1))

import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_1)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_1)
plt.title('ROC Curve for Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_1,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Logistic Regression')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Logistic Regression')
plt.savefig('checkdemo.eps', format='eps')
# Out:
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [0.75, 0.7421203438395416, 0.8048135288065843]
# [[1686  474]
#  [ 606 1554]]

# %% [markdown]
# ## 2. Naive Bayes

# %%
clf_NB = GaussianNB()
clf_NB.fit(X_train, y_train)
pred_NB = clf_NB.predict(X_test)
pred_NB = average(pred_NB)
y_score_2 = clf_NB.predict_proba(X_test)[:,1]
acc2 = accuracy_score(y_test, pred_NB)
f1_score_2 = metrics.f1_score(y_test, pred_NB)
roc_2 = metrics.roc_auc_score(y_test, y_score_2)
print([acc2,f1_score_2,roc_2])
print(confusion_matrix(y_test, pred_NB))

import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_2)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_2)
plt.title('ROC Curve for Naive Bayes')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_2,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Naive Bayes')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Naive Bayes')
# Out:
# [0.6756944444444445, 0.6856630020192955, 0.7095250342935527]
# [[1391  769]
#  [ 632 1528]]
# Text(0.5, 1.0, 'Calibration Curve for Naive Bayes')

# %% [markdown]
# ## 3. KNN

# %%
acc3_list = []
f1_score3_list = []
roc_3_list = []
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,30):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train) 
    pred_KN = neigh.predict(X_test)
    pred_KN = average(pred_KN)
    y_score_3 = neigh.predict_proba(X_test)[:,1]
    acc3_list.append(accuracy_score(y_test, pred_KN))
    f1_score3_list.append(metrics.f1_score(y_test, pred_KN))
    roc_3_list.append(metrics.roc_auc_score(y_test, y_score_3))

# %%
acc3_list.index(max(acc3_list))+1
# Out:
# 4

# %%
neigh = KNeighborsClassifier(n_neighbors=acc3_list.index(max(acc3_list))+1)
neigh.fit(X_train, y_train) 
pred_KN = neigh.predict(X_test)
pred_KN = average(pred_KN)
y_score_3 = neigh.predict_proba(X_test)[:,1]
acc3 = accuracy_score(y_test, pred_KN)
f1_score_3 = metrics.f1_score(y_test, pred_KN)
roc_3 = metrics.roc_auc_score(y_test, y_score_3)
print([acc3,f1_score_3,roc_3])
print(confusion_matrix(y_test, pred_KN))


import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_3)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_3)
plt.title('ROC Curve for KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_3,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'KNN')
plt.legend(loc="lower right")
plt.title('Calibration Curve for KNN')
# Out:
# [0.8340277777777778, 0.8038303693570451, 0.9089423653978052]
# [[2134   26]
#  [ 691 1469]]
# Text(0.5, 1.0, 'Calibration Curve for KNN')

# %% [markdown]
# ## 4. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
acc5=[]
max_depth = []
for i in [2,3,4,5,6,7,8,9,10]:
    clf_DT = DecisionTreeClassifier(random_state=0, max_depth = i)
    clf_DT.fit(X_train, y_train)
    pred_DT = clf_DT.predict(X_test)
    pred_DT = average(pred_DT)
    acc5.append(accuracy_score(pred_DT, y_test))
    max_depth.append(i)
print (max(acc5))
# Out:
# 0.837037037037037

# %%
 best_depth = max_depth[acc5.index(max(acc5))]

# %%
 best_depth
# Out:
# 9

# %%
clf_DT = DecisionTreeClassifier(random_state=0, max_depth = best_depth)
clf_DT.fit(X_train, y_train)
pred_DT = clf_DT.predict(X_test)
pred_DT = average(pred_DT)
y_score_5 = clf_DT.predict_proba(X_test)[:,1]
acc5 = accuracy_score(y_test, pred_DT)
f1_score_5 = metrics.f1_score(y_test, pred_DT)
roc_5 = metrics.roc_auc_score(y_test, y_score_5)
print([acc5,f1_score_5,roc_5])
print(confusion_matrix(y_test, pred_DT))



import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_5)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_5)
plt.title('ROC Curve for Decision Tree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_5,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Decision Tree')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Decision Tree')
# Out:
# [0.837037037037037, 0.8085916258836323, 0.9169083290466391]
# [[2129   31]
#  [ 673 1487]]
# Text(0.5, 1.0, 'Calibration Curve for Decision Tree')

# %% [markdown]
# ## 5. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
acc6=[]
max_depth = []
for i in range(1,10):
    clf_RF = RandomForestClassifier(max_depth=i)
    clf_RF.fit(X_train, y_train) 
    pred_RF = clf_RF.predict(X_test)
    pred_RF = average(pred_RF)
    acc6.append(accuracy_score(pred_RF, y_test))
    max_depth.append(i)
print (max(acc6))
# Out:
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8340277777777778
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
best_depth_6 = max_depth[acc6.index(max(acc6))]

# %%
best_depth_6
# Out:
# 9

# %%
clf_RF = RandomForestClassifier(max_depth=best_depth_6)
clf_RF.fit(X_train, y_train) 
pred_RF = clf_RF.predict(X_test)
pred_RF = average(pred_RF)
y_score_6 = clf_RF.predict_proba(X_test)[:,1]
acc6 = accuracy_score(y_test, pred_RF)
f1_score_6 = metrics.f1_score(y_test, pred_RF)
roc_6 = metrics.roc_auc_score(y_test, y_score_6)
print([acc6,f1_score_6,roc_6])
print(confusion_matrix(y_test, pred_RF))

feature_importances = pd.DataFrame(clf_RF.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)


import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_6)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_6)
plt.title('ROC Curve for Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_6,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Random Forest')
plt.legend(loc="lower right")
plt.title('Calibration Curve for Random Forest')
# Out:
# [0.825462962962963, 0.8384054864980711, 0.9261058599108368]
# [[1610  550]
#  [ 204 1956]]
# /home/visheshkkl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Text(0.5, 1.0, 'Calibration Curve for Random Forest')

# %%
feature_importances
# Out:
#                importance
# MAR_N            0.205734
# MAR              0.186293
# Circularity      0.139700
# MOE_N            0.112942
# Circularity_N    0.104074
# EAR_N            0.094215
# MOE              0.090653
# EAR              0.066389

# %%
X_train_shaped = np.expand_dims(X_train, axis=2)

# %%
X_train_shaped.shape
# Out:
# (6240, 8, 1)

# %%
X_test_shaped = np.expand_dims(X_test, axis=2)

# %%
X_test_shaped.shape
# Out:
# (4320, 8, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers.convolutional import Conv1D
from keras.optimizers import Adam, RMSprop
from keras.layers import Dropout

model = Sequential()

model.add(Conv1D(64, kernel_size = 3, activation = 'relu', input_shape = (8,1)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation = 'sigmoid'))


## Compile Model ##
optimizer = Adam(lr=0.00001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

## Train Model and Check Validation Accuracy ##
model.fit(X_train_shaped, y_train, validation_data = (X_test_shaped,y_test), epochs = 100)
# Out:
# Epoch 1/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.4772 - val_loss: 0.6866 - val_accuracy: 0.4792
# Epoch 2/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.7153 - accuracy: 0.5236 - val_loss: 0.6746 - val_accuracy: 0.5775
# Epoch 3/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6830 - accuracy: 0.5909 - val_loss: 0.6655 - val_accuracy: 0.6245
# Epoch 4/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6776 - accuracy: 0.6215 - val_loss: 0.6584 - val_accuracy: 0.6470
# Epoch 5/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6714 - accuracy: 0.6228 - val_loss: 0.6512 - val_accuracy: 0.6579
# Epoch 6/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6627 - accuracy: 0.6287 - val_loss: 0.6483 - val_accuracy: 0.6590
# Epoch 7/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.6580 - accuracy: 0.6450 - val_loss: 0.6421 - val_accuracy: 0.6711
# Epoch 8/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.6413 - val_loss: 0.6381 - val_accuracy: 0.6731
# Epoch 9/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6481 - accuracy: 0.6527 - val_loss: 0.6348 - val_accuracy: 0.6755
# Epoch 10/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6476 - accuracy: 0.6521 - val_loss: 0.6292 - val_accuracy: 0.6782
# Epoch 11/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6401 - accuracy: 0.6638 - val_loss: 0.6289 - val_accuracy: 0.6780
# Epoch 12/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6351 - accuracy: 0.6651 - val_loss: 0.6225 - val_accuracy: 0.6856
# Epoch 13/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.6333 - accuracy: 0.6776 - val_loss: 0.6179 - val_accuracy: 0.6896
# Epoch 14/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.6692 - val_loss: 0.6127 - val_accuracy: 0.6921
# Epoch 15/100
# 195/195 [==============================] - 1s 3ms/step - loss: 0.6274 - accuracy: 0.6753 - val_loss: 0.6122 - val_accuracy: 0.6919
# Epoch 16/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6225 - accuracy: 0.6804 - val_loss: 0.6070 - val_accuracy: 0.6919
# Epoch 17/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6205 - accuracy: 0.6814 - val_loss: 0.6034 - val_accuracy: 0.6991
# Epoch 18/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.6188 - accuracy: 0.6777 - val_loss: 0.6003 - val_accuracy: 0.6972
# Epoch 19/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6169 - accuracy: 0.6776 - val_loss: 0.5965 - val_accuracy: 0.6986
# Epoch 20/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6128 - accuracy: 0.6808 - val_loss: 0.5956 - val_accuracy: 0.6979
# Epoch 21/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6097 - accuracy: 0.6877 - val_loss: 0.5911 - val_accuracy: 0.7081
# Epoch 22/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6072 - accuracy: 0.6870 - val_loss: 0.5885 - val_accuracy: 0.7083
# Epoch 23/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6095 - accuracy: 0.6798 - val_loss: 0.5874 - val_accuracy: 0.7065
# Epoch 24/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6035 - accuracy: 0.6878 - val_loss: 0.5849 - val_accuracy: 0.7095
# Epoch 25/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 0.6872 - val_loss: 0.5832 - val_accuracy: 0.7065
# Epoch 26/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.6872 - val_loss: 0.5810 - val_accuracy: 0.7079
# Epoch 27/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6001 - accuracy: 0.6880 - val_loss: 0.5805 - val_accuracy: 0.7019
# Epoch 28/100
# 195/195 [==============================] - 1s 3ms/step - loss: 0.5964 - accuracy: 0.6904 - val_loss: 0.5761 - val_accuracy: 0.7130
# Epoch 29/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.6889 - val_loss: 0.5742 - val_accuracy: 0.7109
# Epoch 30/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5946 - accuracy: 0.6902 - val_loss: 0.5719 - val_accuracy: 0.7155
# Epoch 31/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5902 - accuracy: 0.6973 - val_loss: 0.5696 - val_accuracy: 0.7176
# Epoch 32/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.6912 - val_loss: 0.5696 - val_accuracy: 0.7118
# Epoch 33/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.6915 - val_loss: 0.5672 - val_accuracy: 0.7134
# Epoch 34/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5889 - accuracy: 0.6934 - val_loss: 0.5635 - val_accuracy: 0.7188
# Epoch 35/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5863 - accuracy: 0.6963 - val_loss: 0.5634 - val_accuracy: 0.7194
# Epoch 36/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5879 - accuracy: 0.6982 - val_loss: 0.5620 - val_accuracy: 0.7215
# Epoch 37/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.6909 - val_loss: 0.5590 - val_accuracy: 0.7241
# Epoch 38/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5793 - accuracy: 0.7010 - val_loss: 0.5602 - val_accuracy: 0.7167
# Epoch 39/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5808 - accuracy: 0.6963 - val_loss: 0.5565 - val_accuracy: 0.7273
# Epoch 40/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.5800 - accuracy: 0.6982 - val_loss: 0.5549 - val_accuracy: 0.7287
# Epoch 41/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.5752 - accuracy: 0.7013 - val_loss: 0.5537 - val_accuracy: 0.7252
# Epoch 42/100
# 195/195 [==============================] - 1s 3ms/step - loss: 0.5750 - accuracy: 0.7029 - val_loss: 0.5516 - val_accuracy: 0.7329
# Epoch 43/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5741 - accuracy: 0.6970 - val_loss: 0.5491 - val_accuracy: 0.7331
# Epoch 44/100
# 195/195 [==============================] - 1s 3ms/step - loss: 0.5738 - accuracy: 0.7042 - val_loss: 0.5482 - val_accuracy: 0.7315
# Epoch 45/100
# 195/195 [==============================] - 1s 3ms/step - loss: 0.5740 - accuracy: 0.6994 - val_loss: 0.5482 - val_accuracy: 0.7292
# Epoch 46/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5691 - accuracy: 0.7064 - val_loss: 0.5472 - val_accuracy: 0.7343
# Epoch 47/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5709 - accuracy: 0.7022 - val_loss: 0.5444 - val_accuracy: 0.7361
# Epoch 48/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5716 - accuracy: 0.7077 - val_loss: 0.5438 - val_accuracy: 0.7343
# Epoch 49/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.7011 - val_loss: 0.5415 - val_accuracy: 0.7368
# Epoch 50/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7096 - val_loss: 0.5405 - val_accuracy: 0.7384
# Epoch 51/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.7053 - val_loss: 0.5385 - val_accuracy: 0.7352
# Epoch 52/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5654 - accuracy: 0.7024 - val_loss: 0.5366 - val_accuracy: 0.7428
# Epoch 53/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7056 - val_loss: 0.5356 - val_accuracy: 0.7426
# Epoch 54/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.7067 - val_loss: 0.5349 - val_accuracy: 0.7407
# Epoch 55/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.7112 - val_loss: 0.5342 - val_accuracy: 0.7410
# Epoch 56/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7093 - val_loss: 0.5335 - val_accuracy: 0.7428
# Epoch 57/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.7091 - val_loss: 0.5319 - val_accuracy: 0.7435
# Epoch 58/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5572 - accuracy: 0.7064 - val_loss: 0.5310 - val_accuracy: 0.7440
# Epoch 59/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5573 - accuracy: 0.7109 - val_loss: 0.5299 - val_accuracy: 0.7451
# Epoch 60/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.7114 - val_loss: 0.5299 - val_accuracy: 0.7454
# Epoch 61/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7095 - val_loss: 0.5291 - val_accuracy: 0.7426
# Epoch 62/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5543 - accuracy: 0.7135 - val_loss: 0.5290 - val_accuracy: 0.7414
# Epoch 63/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.7131 - val_loss: 0.5269 - val_accuracy: 0.7465
# Epoch 64/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.7135 - val_loss: 0.5268 - val_accuracy: 0.7470
# Epoch 65/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5532 - accuracy: 0.7159 - val_loss: 0.5245 - val_accuracy: 0.7491
# Epoch 66/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.7101 - val_loss: 0.5252 - val_accuracy: 0.7475
# Epoch 67/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5526 - accuracy: 0.7074 - val_loss: 0.5242 - val_accuracy: 0.7491
# Epoch 68/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7162 - val_loss: 0.5234 - val_accuracy: 0.7493
# Epoch 69/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5463 - accuracy: 0.7154 - val_loss: 0.5229 - val_accuracy: 0.7500
# Epoch 70/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.7107 - val_loss: 0.5220 - val_accuracy: 0.7495
# Epoch 71/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5433 - accuracy: 0.7213 - val_loss: 0.5208 - val_accuracy: 0.7493
# Epoch 72/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5494 - accuracy: 0.7127 - val_loss: 0.5195 - val_accuracy: 0.7530
# Epoch 73/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5449 - accuracy: 0.7188 - val_loss: 0.5184 - val_accuracy: 0.7528
# Epoch 74/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5446 - accuracy: 0.7176 - val_loss: 0.5189 - val_accuracy: 0.7486
# Epoch 75/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.7232 - val_loss: 0.5179 - val_accuracy: 0.7495
# Epoch 76/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.7213 - val_loss: 0.5167 - val_accuracy: 0.7528
# Epoch 77/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5417 - accuracy: 0.7231 - val_loss: 0.5160 - val_accuracy: 0.7523
# Epoch 78/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5390 - accuracy: 0.7256 - val_loss: 0.5156 - val_accuracy: 0.7553
# Epoch 79/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.7248 - val_loss: 0.5143 - val_accuracy: 0.7519
# Epoch 80/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5418 - accuracy: 0.7224 - val_loss: 0.5150 - val_accuracy: 0.7521
# Epoch 81/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5362 - accuracy: 0.7237 - val_loss: 0.5148 - val_accuracy: 0.7563
# Epoch 82/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7296 - val_loss: 0.5130 - val_accuracy: 0.7537
# Epoch 83/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5362 - accuracy: 0.7208 - val_loss: 0.5121 - val_accuracy: 0.7588
# Epoch 84/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5382 - accuracy: 0.7269 - val_loss: 0.5117 - val_accuracy: 0.7560
# Epoch 85/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5354 - accuracy: 0.7242 - val_loss: 0.5111 - val_accuracy: 0.7586
# Epoch 86/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5349 - accuracy: 0.7266 - val_loss: 0.5108 - val_accuracy: 0.7569
# Epoch 87/100
# 195/195 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.7290 - val_loss: 0.5100 - val_accuracy: 0.7583
# Epoch 88/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7309 - val_loss: 0.5091 - val_accuracy: 0.7569
# Epoch 89/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5319 - accuracy: 0.7316 - val_loss: 0.5091 - val_accuracy: 0.7590
# Epoch 90/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7308 - val_loss: 0.5080 - val_accuracy: 0.7606
# Epoch 91/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7284 - val_loss: 0.5084 - val_accuracy: 0.7586
# Epoch 92/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5340 - accuracy: 0.7306 - val_loss: 0.5082 - val_accuracy: 0.7583
# Epoch 93/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7260 - val_loss: 0.5066 - val_accuracy: 0.7602
# Epoch 94/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5280 - accuracy: 0.7322 - val_loss: 0.5069 - val_accuracy: 0.7572
# Epoch 95/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5257 - accuracy: 0.7288 - val_loss: 0.5061 - val_accuracy: 0.7590
# Epoch 96/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7343 - val_loss: 0.5050 - val_accuracy: 0.7613
# Epoch 97/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5247 - accuracy: 0.7346 - val_loss: 0.5039 - val_accuracy: 0.7606
# Epoch 98/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5257 - accuracy: 0.7351 - val_loss: 0.5044 - val_accuracy: 0.7611
# Epoch 99/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7349 - val_loss: 0.5042 - val_accuracy: 0.7590
# Epoch 100/100
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.7272 - val_loss: 0.5040 - val_accuracy: 0.7576

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 6, 64)             256
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                12320
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
pred_cnn = model.predict_classes(X_test_shaped)
pred_cnn = average(pred_cnn)
y_score_7 = model.predict_proba(X_test_shaped)
acc7 = accuracy_score(y_test, np.array(pred_cnn))
f1_score_7 = metrics.f1_score(y_test, pred_cnn)
roc_7 = metrics.roc_auc_score(y_test, y_score_7)
print([acc7,f1_score_7,roc_7])
print(confusion_matrix(y_test, pred_cnn))



import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1],'r--')
fpr, tpr, thresholds = roc_curve(y_test, y_score_7)
plt.plot(fpr, tpr, label= 'ROC curve (area = %0.2f)' % roc_7)
plt.title('ROC Curve for CNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()


from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_7,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'CNN')
plt.legend(loc="lower right")
plt.title('Calibration Curve for CNN')
# Out:
# WARNING:tensorflow:From <ipython-input-28-3872f9bf715a>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# WARNING:tensorflow:From <ipython-input-28-3872f9bf715a>:3: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
# [0.7752314814814815, 0.7893252332393145, 0.8586966306584363]
# [[1530  630]
#  [ 341 1819]]
# Text(0.5, 1.0, 'Calibration Curve for CNN')

# %%
acc_total = {'Model':['Logistic Regression','Naive Bayes', 'KNN','Decision Tree','Random Forest', 'CNN'],
        'Accuracy':[acc1,acc2, acc3, acc5,acc6,acc7]}
acc_total=pd.DataFrame(acc_total)
acc_total=acc_total.set_index('Model')
acc_total
plt.plot(acc_total['Accuracy'])
plt.xticks(rotation=45)
acc_total
# Out:
#                      Accuracy
# Model
# Logistic Regression  0.750000
# Naive Bayes          0.675694
# KNN                  0.834028
# Decision Tree        0.837037
# Random Forest        0.825463
# CNN                  0.775231

# %%
plt.figure(figsize=(10,8))
plt.plot([0, 1], [0, 1],'r--')
fpr_1, tpr_1, thresholds = roc_curve(y_test, y_score_1)
fpr_2, tpr_2, thresholds = roc_curve(y_test, y_score_2)
fpr_3, tpr_3, thresholds = roc_curve(y_test, y_score_3)
fpr_5, tpr_5, thresholds = roc_curve(y_test, y_score_5)
fpr_6, tpr_6, thresholds = roc_curve(y_test, y_score_6)
fpr_7, tpr_7, thresholds = roc_curve(y_test, y_score_7)
plt.plot(fpr_1, tpr_1, label= "Logistic Regression")
plt.plot(fpr_2, tpr_2, label= "Naive Bayes")
plt.plot(fpr_3, tpr_3, label= "KNN")
plt.plot(fpr_5, tpr_5, label= "Decision Tree")
plt.plot(fpr_6, tpr_6, label= "Random Forest")
plt.plot(fpr_7, tpr_7, label= "CNN")
plt.title('ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
from sklearn.calibration import calibration_curve
plt.figure(figsize=(8,8))
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_1,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Logistic Regression')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_2,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Naive Bayes')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_3,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'KNN')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_5,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Decision Tree')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_6,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'Random Forest')
fraction_of_positives, mean_predicted_value=calibration_curve(y_test,y_score_7,n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives,"s-",
                 label="%s" % 'CNN')
plt.legend(loc="lower right")
plt.title('Calibration Curves')
# Out:
# Text(0.5, 1.0, 'Calibration Curves')
